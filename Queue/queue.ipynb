# %%
queue = []

# Enqueue
queue.append('A')
queue.append('B')
queue.append('C')
print("Queue: ", queue)

# Dequeue
element = queue.pop(0)
print("Dequeue: ", element)

# Peek
frontElement = queue[0]
print("Peek: ", frontElement)

# isEmpty
isEmpty = not bool(queue)
print("isEmpty: ", isEmpty)

# Size
print("Size: ", len(queue))
# Out:
# Queue:  ['A', 'B', 'C']
# Dequeue:  A
# Peek:  B
# isEmpty:  False
# Size:  2

# %%
class Queue:
    def __init__(self):
        self.queue=[]

    def Enqueue(self,data):
        self.queue.append(data)
        return
    
    def Dequeue(self):
        if len(self.queue)==0:
            print('can not dequeue')
            return
        else:
            element=self.queue.pop(0)
            print("dequeued:", element)
            return
    
    def peek(self):
        if len(self.queue)==0:
            print('queue is empty')
            return
        else:
            print("peek:", self.queue[0])
            return
    
    def isEmpty(self):
        a=not bool(self.queue)
        print("isEmpty:",a)
        return
    
    def size(self):
        print("length of queue:", len(self.queue))
        return
    
    def display(self):
        if len(self.queue) == 0:
            print("empty")
            return
        print("queue:", *self.queue)
            
            


q=Queue()
q.Dequeue()
q.Enqueue(1)
q.Enqueue(2)
q.Enqueue(3)
q.Enqueue(4)
q.Enqueue(5)
q.display()
q.Dequeue()
q.display()
q.peek()
q.isEmpty()
q.size()
# Out:
# can not dequeue
# queue: [1, 2, 3, 4, 5]
# dequeued: 1
# queue: [2, 3, 4, 5]
# peek: 2
# isEmpty: False
# length of queue: 4

# %%
class Queue:
    def __init__(self):
        self.queue = []

    def enqueue(self, data):
        self.queue.append(data)

    def dequeue(self):
        if len(self.queue) == 0:
            print("Cannot dequeue")
            return
        else:
            element = self.queue.pop(0)
            print("Dequeued:", element)

    def peek(self):
        if len(self.queue) == 0:
            print("Queue is empty")
            return
        else:
            print("peek:", self.queue[0])
            return

    def is_empty(self):
        a = not bool(self.queue)
        print("Is empty:", a)
    
    def size(self):
        print("length of queue:", len(self.queue))
        return
    
    def display(self):
        if len(self.queue) == 0:
            print("Empty")
        else:
            print(*self.queue)


q = Queue()
q.dequeue()
q.enqueue(1)
q.enqueue(2)
q.enqueue(3)
q.enqueue(4)
q.enqueue(5)
q.display()
q.dequeue()
q.display()
q.peek()
q.is_empty()
# Out:
# Cannot dequeue
# 1 2 3 4 5
# Dequeued: 1
# 2 3 4 5
# peek: 2
# Is empty: False

# %%
class Queue:
    """A simple Queue implementation using a list."""
    
    def __init__(self):
        """Initialize an empty queue."""
        self.queue = []

    def enqueue(self, data):
        """Add an element to the end of the queue."""
        self.queue.append(data)

    def dequeue(self):
        """Remove and return the front element of the queue. Returns None if empty."""
        if self.is_empty():
            print("Cannot dequeue: Queue is empty")
            return None
        return self.queue.pop(0)

    def peek(self):
        """Return the front element without removing it. Returns None if empty."""
        if self.is_empty():
            print("Queue is empty")
            return None
        return self.queue[0]

    def is_empty(self):
        """Check if the queue is empty. Returns True/False."""
        return len(self.queue) == 0
    

    def display(self):
        """Display all elements in the queue."""
        if self.is_empty():
            print("Queue is empty")
        else:
            print("Queue:", *self.queue)

# Example Usage
q = Queue()
print("Dequeued:", q.dequeue())  # Should print queue is empty
q.enqueue(1)
q.enqueue(2)
q.enqueue(3)
q.enqueue(4)
q.enqueue(5)
q.display()
print("Dequeued:", q.dequeue())  # Should return 1
q.display()
print("Front element:", q.peek())  # Should return 2
print("Is queue empty?", q.is_empty())  # Should return False
# Out:
# Cannot dequeue: Queue is empty
# Dequeued: None
# Queue: 1 2 3 4 5
# Dequeued: 1
# Queue: 2 3 4 5
# Front element: 2
# Is queue empty? False

# %%
class CircularQueue:
    def __init__(self, size):
        self.size = size
        self.queue = [None] * size  # Fixed-size list
        self.front = -1
        self.rear = -1

    def is_empty(self):
        return self.front == -1

    def is_full(self):
        return (self.rear + 1) % self.size == self.front

    def enqueue(self, item):
        if self.is_full():
            print("Queue is full. Cannot enqueue.")
            return

        if self.is_empty():
            self.front = self.rear = 0
        else:
            self.rear = (self.rear + 1) % self.size

        self.queue[self.rear] = item

    def dequeue(self):
        if self.is_empty():
            print("Queue is empty. Cannot dequeue.")
            return None

        removed = self.queue[self.front]
        if self.front == self.rear:
            # Only one element was in the queue
            self.front = self.rear = -1
        else:
            self.front = (self.front + 1) % self.size

        return removed

    def peek(self):
        if self.is_empty():
            print("Queue is empty.")
            return None
        return self.queue[self.front]

    def display(self):
        if self.is_empty():
            print("Queue is empty.")
            return

        print("Queue elements:", end=" ")
        i = self.front
        while True:
            print(self.queue[i], end=" ")
            if i == self.rear:
                break
            i = (i + 1) % self.size
        print()

# %%
class Node:
    """A node in a doubly linked list."""
    def __init__(self, data):
        self.data = data
        self.prev = None
        self.next = None

class Deque:
    """Deque implementation using a doubly linked list."""
    def __init__(self):
        self.front = None
        self.rear = None

    def is_empty(self):
        return self.front is None

    def append(self, data):
        """Add to rear."""
        new_node = Node(data)
        if self.is_empty():
            self.front = self.rear = new_node
        else:
            self.rear.next = new_node
            new_node.prev = self.rear
            self.rear = new_node

    def appendleft(self, data):
        """Add to front."""
        new_node = Node(data)
        if self.is_empty():
            self.front = self.rear = new_node
        else:
            new_node.next = self.front
            self.front.prev = new_node
            self.front = new_node

    def pop(self):
        """Remove from rear."""
        if self.is_empty():
            raise IndexError("pop from empty deque")
        data = self.rear.data
        if self.front == self.rear:
            self.front = self.rear = None
        else:
            self.rear = self.rear.prev
            self.rear.next = None
        return data

    def popleft(self):
        """Remove from front."""
        if self.is_empty():
            raise IndexError("popleft from empty deque")
        data = self.front.data
        if self.front == self.rear:
            self.front = self.rear = None
        else:
            self.front = self.front.next
            self.front.prev = None
        return data

    def peek_front(self):
        if self.is_empty():
            raise IndexError("deque is empty")
        return self.front.data

    def peek_rear(self):
        if self.is_empty():
            raise IndexError("deque is empty")
        return self.rear.data

    def display(self):
        """Print elements from front to rear."""
        temp = self.front
        print("Deque:", end=" ")
        while temp:
            print(temp.data, end=" ")
            temp = temp.next
        print()

# %%
class Node:
    """
    A node of the singly linked list.
    """
    def __init__(self, data):
        self.data = data
        self.next = None


class Queue:
    """
    A queue implemented using a singly linked list.
    Supports enqueue, dequeue, and peek operations.
    """
    def __init__(self):
        self.front = None
        self.rear = None

    def is_empty(self):
        """
        Check if the queue is empty.
        """
        return self.front is None

    def enqueue(self, item):
        """
        Add an item to the end of the queue.
        """
        new_node = Node(item)

        if self.rear is None:
            # First element being added
            self.front = self.rear = new_node
        else:
            self.rear.next = new_node
            self.rear = new_node

    def dequeue(self):
        """
        Remove and return the front item of the queue.
        """
        if self.is_empty():
            print("Queue Underflow! Cannot dequeue.")
            return None

        result = self.front.data
        self.front = self.front.next

        if self.front is None:
            # If the queue becomes empty after dequeue
            self.rear = None

        return result

    def peek(self):
        """
        Return the front item without removing it.
        """
        if self.is_empty():
            return None
        return self.front.data

    def display(self):
        """
        Display all elements of the queue.
        """
        current = self.front
        while current:
            print(current.data, end=" -> ")
            current = current.next
        print("None")
